# %% [markdown]
# ## Import Dependencies

# %%
# !brew install swig
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
#
# You have 32 outdated formulae installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# ...
# To reinstall 4.0.2, run:
#   brew reinstall swig

# %%
# !pip install -q "gym[box2d]" pyglet==1.3.2
# Out:
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2470 lines of output]
#       Using setuptools (version 56.0.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-12.2-x86_64-3.8
#       creating build/lib.macosx-12.2-x86_64-3.8/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D
#       copying library/Box2D/__init__.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D
#       creating build/lib.macosx-12.2-x86_64-3.8/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
# ...

# %%
# !pip install pyglet
# !python3.8 -m pip install --upgrade pip

# %%
#I cant install gym box 2d :(
# !pip install "gym[box2d]"
# Out:
# ...
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2470 lines of output]
#       Using setuptools (version 56.0.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-12.2-x86_64-3.8
#       creating build/lib.macosx-12.2-x86_64-3.8/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D
#       copying library/Box2D/__init__.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D
#       creating build/lib.macosx-12.2-x86_64-3.8/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.macosx-12.2-x86_64-3.8/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
# ...

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Test Environment

# %%
environment="CarRacing-v0"

# %%
env=gym.make(environment)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2b/8swfrzvj1b10sb2dt02_4g6c0000gn/T/ipykernel_12621/388740865.py in <module>
# ----> 1 env=gym.make(environment)
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/gym/envs/registration.py in make(id, **kwargs)
#     233
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#     236
#     237
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#     127             logger.info("Making new env: %s", path)
#     128         spec = self.spec(path)
# --> 129         env = spec.make(**kwargs)
#     130         return env
#     131
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/gym/envs/registration.py in make(self, **kwargs)
#      87             env = self.entry_point(**_kwargs)
# ...

# %%
episodes=5
for episode in range(1, episodes+1):
    state=env.reset()
    score=0
    done=False
    
    while not done:
        env.render()
        action=env.action_space.sample()
        n_state, rewards, done, info=env.step(action)
        score+=reward
    print(f"Episode : {episode} Score : {score}")

env.close()

# %%
env.action_space.sample()

# %%
env.observation_space.sample()

# %% [markdown]
# ## Train Model

# %%
log_path=os.path.join("Training", "Logs")

# %%
model=PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=40000)

# %% [markdown]
# ## Save Model

# %%
ppo_path=os.path.join("Training","Saved Model", "PPO_Driving_model")

# %%
model.save(ppo_path)

# %% [markdown]
# ## Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10,render=True)

# %%
env.close()

# %%
obs=ens.reset()
while True:
    sction,_=model.predict(obs)
    obs, rewards, done, info=env.step(action)
    env.render()

# %%
env.close()
